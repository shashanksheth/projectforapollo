# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import winsorize

# %%
df = pd.read_excel('task2_stock_data.xlsx')

# %%
def calculateBeta (asofdate, window, frequency):
    #calculate start date based on file
    firstdate=df.iloc[0,0]
    
    #set period according to window entered
    if window=="1y":
        period=-1
    elif window=="2y":
        period=-2
    else:
        print("Incorrect window entered. Options are: '1y' or '2y'.")
        return
    
    try:
        windowstart = pd.to_datetime(asofdate) + pd.DateOffset(years=period)
    except:
        print("Incorrect asofdate entered. Please use the following format: 'YYYY-MM-DD'")
        return
    
    if firstdate > pd.to_datetime(asofdate) + pd.DateOffset(years=period):
        print (f"WARNING: The time between the first date in the file <{firstdate.strftime('%Y-%m-%d')}> and the given asofdate <{asofdate}> is less than the given window <{window}>. The calculation is therefore performed on a shorter window of returns.")
    
    #trim the dataframe by asofdate and period
    #sort so that the return calculation includes the latest returns
    window_df = df.loc[(df['date'] < asofdate) & (df['date'] >= windowstart)].sort_values(by='date', ascending=False) 
    
    #set freq based on frequency entered
    if frequency=="daily":
        freq=1
    elif frequency=="weekly":
        freq=5
    elif frequency=="bi-weekly":
        freq=5*2
    elif frequency=="monthly":
        #assumption. 20.97 was the average days in a month in the given file
        freq=21
    elif frequency=="quarterly":
        #assumption. multiplied monthly by 4
        freq=21*4
    else:
        print("Incorrect frequency entered. Options are: 'daily','bi-weekly','monthly', or 'quarterly'.")
        return
        
    #trim the dataframe by frequency
    freq_window_df = window_df.iloc[::freq, :]
    
    #calculate returns, winsorize, and store in a dictionary
    freq_window_df.set_index("date", inplace=True)
    returns={}
    for column in freq_window_df:
        data = freq_window_df[column]
        log_returns = np.log(data/data.shift())
        log_returns_winsorized = winsorize(log_returns,limits=[0.05, 0.05])
        returns[column]=log_returns_winsorized[1:]
    
    #calculate covariances and store in a dictionary
    covariances={}
    for key in returns:
        covariances[key] = np.cov(returns[key],returns["SPY US Equity"],bias=True)[1][0]
    
    #calculate market variance
    market_variance=np.var(returns["SPY US Equity"])
    
    #calculate betas store in a dictionary. Rounded to 10 due to lost precision issues
    betas = {}
    for key in covariances:
        betas[key]=round((covariances[key]/market_variance),10)
    
    #return the result
    return betas

# %%
calculateBeta("2021-10-31","1y","daily")
# Out:
# {'APTMU US Equity': nan,
#  'AAC US Equity': nan,
#  'CWEN US Equity': 0.8989808641,
#  'BHC US Equity': 1.0212363,
#  'FACA US Equity': nan,
#  'AFT US Equity': 0.1748769343,
#  'ARBG US Equity': nan,
#  'AAC/WS US Equity': nan,
#  'BKKT US Equity': nan,
#  'CWEN/A US Equity': 0.9708069857,
#  'AGAC US Equity': nan,
#  'ARBGU US Equity': nan,
#  'FACA/WS US Equity': nan,
#  'ACAQ/U US Equity': nan,
#  'ARGUU US Equity': nan,
#  'CYDY US Equity': 0.3960686469,
#  'FACT US Equity': nan,
#  'AGAC/WS US Equity': nan,
#  'BKLN US Equity': 0.1119000666,
#  'ACDI/U US Equity': nan,
#  'ASZ US Equity': nan,
#  'FLAG/U US Equity': nan,
#  'BWCAU US Equity': nan,
#  'AGGRU US Equity': nan,
#  'ADALU US Equity': nan,
#  'CYRX US Equity': 1.3634391243,
#  'AHLD US Equity': nan,
#  'FLYA/U US Equity': nan,
#  'DCRN US Equity': nan,
#  'BYND US Equity': 0.7323806122,
#  'AEAEU US Equity': nan,
#  'ATUS US Equity': 0.7624803832,
#  'AMCIU US Equity': nan,
#  'FMIVU US Equity': nan,
#  'AFACU US Equity': nan,
#  'AVAN US Equity': nan,
#  'DDD US Equity': 2.3167928838,
#  'CBRGU US Equity': nan,
#  'FPAC US Equity': nan,
#  'AMRS US Equity': 1.3054422662,
#  'AFRM US Equity': nan,
#  'BCSAU US Equity': nan,
#  'DGNU US Equity': nan,
#  'FRWAU US Equity': nan,
#  'CFFVW US Equity': nan,
#  'APN/U US Equity': nan,
#  'CFV US Equity': nan,
#  'DHCA US Equity': nan,
#  'FSLY US Equity': 1.0164405848,
#  'CFIV US Equity': nan,
#  'HTAQ/U US Equity': nan,
#  'CHGG US Equity': 0.6912326209,
#  'DHCAW US Equity': nan,
#  'FSNB US Equity': nan,
#  'HWELU US Equity': nan,
#  'IWM US Equity': 1.258072346,
#  'CMLTU US Equity': nan,
#  'ENNVW US Equity': nan,
#  'DISAU US Equity': nan,
#  'FSNB/WS US Equity': nan,
#  'ENPC US Equity': 0.0319328753,
#  'HYG US Equity': 0.2186851571,
#  'CMPR US Equity': 1.2149988617,
#  'IWN US Equity': 1.182097922,
#  'DISH US Equity': 1.3127058062,
#  'FXI US Equity': 0.7761323121,
#  'CNDB/U US Equity': nan,
#  'IACC US Equity': nan,
#  'JOFF US Equity': nan,
#  'ENPC/WS US Equity': -0.1459831031,
#  'DOCN US Equity': nan,
#  'FZT/U US Equity': nan,
#  'IIAC/WS US Equity': nan,
#  'COMM US Equity': 1.535357273,
#  'JOFFW US Equity': nan,
#  'ENTFU US Equity': nan,
#  'DPCSU US Equity': nan,
#  'IQMDU US Equity': nan,
#  'CORS/U US Equity': nan,
#  'GCI US Equity': 1.3364867888,
#  'JUN/U US Equity': nan,
#  'EOCW/U US Equity': nan,
#  'EBACU US Equity': nan,
#  'ISAA US Equity': nan,
#  'GGMCU US Equity': nan,
#  'CVII US Equity': nan,
#  'KVSA US Equity': nan,
#  'EPD US Equity': 0.8868865781,
#  'EHC US Equity': 0.5497518152,
#  'ITRI US Equity': 1.3874116643,
#  'KVSC US Equity': nan,
#  'LCAAU US Equity': nan,
#  'GM US Equity': 1.2109804082,
#  'LCAHU US Equity': nan,
#  'ENGH US Equity': -0.1429172265,
#  'ET US Equity': 1.2328462194,
#  'GMBEQ US Equity': 0.0,
#  'LBTYK US Equity': 0.8138613213,
#  'MCAAU US Equity': nan,
#  'GTPAU US Equity': nan,
#  'MPRAU US Equity': nan,
#  'LCID US Equity': 0.9903568075,
#  'LIONU US Equity': nan,
#  'EXPE US Equity': 1.2490820599,
#  'MDH US Equity': nan,
#  'GTPBU US Equity': nan,
#  'MTAL/U US Equity': nan,
#  'LDHAU US Equity': nan,
#  'LOCC/U US Equity': nan,
#  'TSPQ US Equity': nan,
#  'GVCIU US Equity': nan,
#  'LEGAU US Equity': nan,
#  'MTBC US Equity': 1.2522133029,
#  'MDH/WS US Equity': nan,
#  'LOKM US Equity': nan,
#  'TSPQ/WS US Equity': nan,
#  'LGSTU US Equity': nan,
#  'HAE US Equity': 0.7204423625,
#  'MYPS US Equity': nan,
#  'MITA US Equity': nan,
#  'LPSN US Equity': 1.1340220377,
#  'LGVCU US Equity': nan,
#  'MITAU US Equity': nan,
#  'TWLV US Equity': nan,
#  'HCVIU US Equity': nan,
#  'NCLH US Equity': 1.8140955103,
#  'LHAA US Equity': nan,
#  'MARA US Equity': 3.6177472931,
#  'HERA US Equity': nan,
#  'NDAC US Equity': nan,
#  'MITAW US Equity': nan,
#  'TWLVW US Equity': nan,
#  'HPLTU US Equity': nan,
#  'MBSC/U US Equity': nan,
#  'NFNT/U US Equity': nan,
#  'STEM US Equity': 1.9610829811,
#  'ML US Equity': 0.5110309566,
#  'U US Equity': 1.2857472463,
#  'NPABU US Equity': nan,
#  'PTON US Equity': 0.615262083,
#  'STRE/U US Equity': nan,
#  'NI US Equity': 0.4107181541,
#  'MLAIU US Equity': nan,
#  'UBER US Equity': 1.4738336954,
#  'NRG US Equity': 1.0092806083,
#  'RBAC US Equity': 0.1149357495,
#  'SVFB US Equity': nan,
#  'SHCAU US Equity': nan,
#  'WALDU US Equity': nan,
#  'USCTU US Equity': nan,
#  'SVFC US Equity': nan,
#  'ORGN US Equity': 0.6731085467,
#  'SKIL US Equity': 0.1938861468,
#  'RCFA/U US Equity': nan,
#  'VERI US Equity': 1.9026541825,
#  'WCGXX US Equity': 0.0,
#  'OSH US Equity': 1.0127890638,
#  'SLCR US Equity': nan,
#  'SVNAU US Equity': nan,
#  'ROSEU US Equity': nan,
#  'PDOT/U US Equity': nan,
#  'PACX US Equity': nan,
#  'WEJO US Equity': nan,
#  'SZZLU US Equity': nan,
#  'RRAC/U US Equity': nan,
#  'PEGRU US Equity': nan,
#  'SLCRW US Equity': nan,
#  'PCPC US Equity': nan,
#  'WIX US Equity': 0.8244984713,
#  'PGSS/U US Equity': nan,
#  'SNII US Equity': nan,
#  'SANBU US Equity': nan,
#  'TCVA US Equity': nan,
#  'PCPC/WS US Equity': nan,
#  'SEDA/U US Equity': nan,
#  'XLU US Equity': 0.5040487566,
#  'PHIC US Equity': nan,
#  'SNII/WS US Equity': nan,
#  'YTPG US Equity': nan,
#  'TETCU US Equity': nan,
#  'POW US Equity': nan,
#  'PDD US Equity': 1.4634610083,
#  'SOFI US Equity': nan,
#  'ZINGU US Equity': nan,
#  'TMAC US Equity': nan,
#  'PRFT US Equity': 1.2399477326,
#  'SPOT US Equity': 1.3639967816,
#  'VICI US Equity': 0.9787111878,
#  'PRPC US Equity': nan,
#  'TMAC/WS US Equity': nan,
#  'VMGAU US Equity': nan,
#  'TOACU US Equity': nan,
#  'PSTH US Equity': 0.608074813,
#  'SPY US Equity': 1.0,
#  'VOSO US Equity': nan,
#  'TRAQ/U US Equity': nan,
#  'VPCC US Equity': nan,
#  'ZTAQU US Equity': nan,
#  'TRCA US Equity': nan,
#  'VST US Equity': 0.9163667199,
#  'VTIQ US Equity': nan,
#  'TRCA/WS US Equity': nan,
#  'TSIB US Equity': nan,
#  'VTIQW US Equity': nan,
#  'W US Equity': 1.1222617224,
#  'TEKKW US Equity': nan}

# %%
calculateBeta("2021-10-31","1y","weekly")
# Out:
# {'APTMU US Equity': nan,
#  'AAC US Equity': nan,
#  'CWEN US Equity': 1.7677381811,
#  'BHC US Equity': 1.4023917239,
#  'FACA US Equity': nan,
#  'AFT US Equity': 0.262832467,
#  'ARBG US Equity': nan,
#  'AAC/WS US Equity': nan,
#  'BKKT US Equity': nan,
#  'CWEN/A US Equity': 1.7688540814,
#  'AGAC US Equity': nan,
#  'ARBGU US Equity': nan,
#  'FACA/WS US Equity': nan,
#  'ACAQ/U US Equity': nan,
#  'ARGUU US Equity': nan,
#  'CYDY US Equity': 1.2724733897,
#  'FACT US Equity': nan,
#  'AGAC/WS US Equity': nan,
#  'BKLN US Equity': 0.1126273417,
#  'ACDI/U US Equity': nan,
#  'ASZ US Equity': nan,
#  'FLAG/U US Equity': nan,
#  'BWCAU US Equity': nan,
#  'AGGRU US Equity': nan,
#  'ADALU US Equity': nan,
#  'CYRX US Equity': 4.1562752877,
#  'AHLD US Equity': nan,
#  'FLYA/U US Equity': nan,
#  'DCRN US Equity': nan,
#  'BYND US Equity': 0.6298104042,
#  'AEAEU US Equity': nan,
#  'ATUS US Equity': 0.9176213371,
#  'AMCIU US Equity': nan,
#  'FMIVU US Equity': nan,
#  'AFACU US Equity': nan,
#  'AVAN US Equity': nan,
#  'DDD US Equity': 4.8782393385,
#  'CBRGU US Equity': nan,
#  'FPAC US Equity': nan,
#  'AMRS US Equity': 2.1090093891,
#  'AFRM US Equity': nan,
#  'BCSAU US Equity': nan,
#  'DGNU US Equity': nan,
#  'FRWAU US Equity': nan,
#  'CFFVW US Equity': nan,
#  'APN/U US Equity': nan,
#  'CFV US Equity': nan,
#  'DHCA US Equity': nan,
#  'FSLY US Equity': 2.9940129268,
#  'CFIV US Equity': nan,
#  'HTAQ/U US Equity': nan,
#  'CHGG US Equity': 1.6522681146,
#  'DHCAW US Equity': nan,
#  'FSNB US Equity': nan,
#  'HWELU US Equity': nan,
#  'IWM US Equity': 1.4828691407,
#  'CMLTU US Equity': nan,
#  'ENNVW US Equity': nan,
#  'DISAU US Equity': nan,
#  'FSNB/WS US Equity': nan,
#  'ENPC US Equity': 0.1392471582,
#  'HYG US Equity': 0.1856878774,
#  'CMPR US Equity': 1.3335659806,
#  'IWN US Equity': 1.1201331657,
#  'DISH US Equity': 1.2758712422,
#  'FXI US Equity': 1.1025961407,
#  'CNDB/U US Equity': nan,
#  'IACC US Equity': nan,
#  'JOFF US Equity': nan,
#  'ENPC/WS US Equity': 0.1515548929,
#  'DOCN US Equity': nan,
#  'FZT/U US Equity': nan,
#  'IIAC/WS US Equity': nan,
#  'COMM US Equity': 1.7545802025,
#  'JOFFW US Equity': nan,
#  'ENTFU US Equity': nan,
#  'DPCSU US Equity': nan,
#  'IQMDU US Equity': nan,
#  'CORS/U US Equity': nan,
#  'GCI US Equity': 0.784086576,
#  'JUN/U US Equity': nan,
#  'EOCW/U US Equity': nan,
#  'EBACU US Equity': nan,
#  'ISAA US Equity': nan,
#  'GGMCU US Equity': nan,
#  'CVII US Equity': nan,
#  'KVSA US Equity': nan,
#  'EPD US Equity': 0.8280938433,
#  'EHC US Equity': 0.8028356366,
#  'ITRI US Equity': 1.9726221947,
#  'KVSC US Equity': nan,
#  'LCAAU US Equity': nan,
#  'GM US Equity': 1.2614210595,
#  'LCAHU US Equity': nan,
#  'ENGH US Equity': -0.2481510957,
#  'ET US Equity': 0.2818384579,
#  'GMBEQ US Equity': 0.0,
#  'LBTYK US Equity': 0.8949697658,
#  'MCAAU US Equity': nan,
#  'GTPAU US Equity': nan,
#  'MPRAU US Equity': nan,
#  'LCID US Equity': 3.0226420133,
#  'LIONU US Equity': nan,
#  'EXPE US Equity': 1.2196571004,
#  'MDH US Equity': nan,
#  'GTPBU US Equity': nan,
#  'MTAL/U US Equity': nan,
#  'LDHAU US Equity': nan,
#  'LOCC/U US Equity': nan,
#  'TSPQ US Equity': nan,
#  'GVCIU US Equity': nan,
#  'LEGAU US Equity': nan,
#  'MTBC US Equity': 0.9047731878,
#  'MDH/WS US Equity': nan,
#  'LOKM US Equity': nan,
#  'TSPQ/WS US Equity': nan,
#  'LGSTU US Equity': nan,
#  'HAE US Equity': 0.9209126762,
#  'MYPS US Equity': nan,
#  'MITA US Equity': nan,
#  'LPSN US Equity': 1.205581102,
#  'LGVCU US Equity': nan,
#  'MITAU US Equity': nan,
#  'TWLV US Equity': nan,
#  'HCVIU US Equity': nan,
#  'NCLH US Equity': 2.1728383852,
#  'LHAA US Equity': nan,
#  'MARA US Equity': 3.9489924809,
#  'HERA US Equity': nan,
#  'NDAC US Equity': nan,
#  'MITAW US Equity': nan,
#  'TWLVW US Equity': nan,
#  'HPLTU US Equity': nan,
#  'MBSC/U US Equity': nan,
#  'NFNT/U US Equity': nan,
#  'STEM US Equity': 4.2412933818,
#  'ML US Equity': 0.9024604205,
#  'U US Equity': 1.9225276409,
#  'NPABU US Equity': nan,
#  'PTON US Equity': 1.3366963983,
#  'STRE/U US Equity': nan,
#  'NI US Equity': 0.4503259145,
#  'MLAIU US Equity': nan,
#  'UBER US Equity': 2.369480492,
#  'NRG US Equity': 1.3695493001,
#  'RBAC US Equity': 0.1141959909,
#  'SVFB US Equity': nan,
#  'SHCAU US Equity': nan,
#  'WALDU US Equity': nan,
#  'USCTU US Equity': nan,
#  'SVFC US Equity': nan,
#  'ORGN US Equity': 0.7512518746,
#  'SKIL US Equity': 0.2868396052,
#  'RCFA/U US Equity': nan,
#  'VERI US Equity': 4.3210574488,
#  'WCGXX US Equity': 0.0,
#  'OSH US Equity': 2.021508414,
#  'SLCR US Equity': nan,
#  'SVNAU US Equity': nan,
#  'ROSEU US Equity': nan,
#  'PDOT/U US Equity': nan,
#  'PACX US Equity': nan,
#  'WEJO US Equity': nan,
#  'SZZLU US Equity': nan,
#  'RRAC/U US Equity': nan,
#  'PEGRU US Equity': nan,
#  'SLCRW US Equity': nan,
#  'PCPC US Equity': nan,
#  'WIX US Equity': 1.7290496094,
#  'PGSS/U US Equity': nan,
#  'SNII US Equity': nan,
#  'SANBU US Equity': nan,
#  'TCVA US Equity': nan,
#  'PCPC/WS US Equity': nan,
#  'SEDA/U US Equity': nan,
#  'XLU US Equity': 0.6577113251,
#  'PHIC US Equity': nan,
#  'SNII/WS US Equity': nan,
#  'YTPG US Equity': nan,
#  'TETCU US Equity': nan,
#  'POW US Equity': nan,
#  'PDD US Equity': 4.2553945441,
#  'SOFI US Equity': nan,
#  'ZINGU US Equity': nan,
#  'TMAC US Equity': nan,
#  'PRFT US Equity': 1.2854462276,
#  'SPOT US Equity': 2.5529064062,
#  'VICI US Equity': 0.7500951404,
#  'PRPC US Equity': nan,
#  'TMAC/WS US Equity': nan,
#  'VMGAU US Equity': nan,
#  'TOACU US Equity': nan,
#  'PSTH US Equity': 1.3414603731,
#  'SPY US Equity': 1.0,
#  'VOSO US Equity': nan,
#  'TRAQ/U US Equity': nan,
#  'VPCC US Equity': nan,
#  'ZTAQU US Equity': nan,
#  'TRCA US Equity': nan,
#  'VST US Equity': 1.1106274109,
#  'VTIQ US Equity': nan,
#  'TRCA/WS US Equity': nan,
#  'TSIB US Equity': nan,
#  'VTIQW US Equity': nan,
#  'W US Equity': 0.6192768975,
#  'TEKKW US Equity': nan}

# %%
# # checking to see if the result is identical to the linear regression method.
# # I chose to calculate covariance and variance to:
# # (1) better understand the calculation in-depth, and
# # (2) my guess is that linear regression is slower and/or more memory intensive

# from sklearn.linear_model import LinearRegression

# X = returns['SPY US Equity'].reshape(-1, 1)
# Y = returns['CWEN US Equity'].reshape(-1, 1)
 
# lin_regr = LinearRegression()
# lin_regr.fit(X, Y)
 
# lin_regr.coef_[0, 0]
